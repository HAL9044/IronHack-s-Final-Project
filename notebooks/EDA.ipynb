# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./DFRAMEAMPLIADO.csv", low_memory=False)
data.shape
# Out:
# (100745, 24)

# %%
data
# Out:
#         Unnamed: 0   Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  \
# 0                0  129900          2      3     90.0      0                0
# 1                1  175000          2      3    112.0      0                0
# 2                2   55000          1      4    100.0      0                0
# 3                3   36000          1      3     56.0      0                0
# 4                4   55000          1      3     60.0      0                0
# ...            ...     ...        ...    ...      ...    ...              ...
# 100740      100740  345000          3      3   8454.0      0                0
# 100741      100741  600000          4      5    380.0      0                0
# 100742      100742  231000          2      1     55.0      0                0
# 100743      100743  121500          1      2     74.0      0                0
# 100744      100744  235000          1      1     66.0      0                0
#
# ...

# %%
data = data.drop('Links', axis=1)
data = data.drop('Unnamed: 0', axis=1)

# %%
data.shape
# Out:
# (100745, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100745 entries, 0 to 100744
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Price                 100745 non-null  int64
#  1   Bathrooms             100745 non-null  int64
#  2   Rooms                 100745 non-null  int64
#  3   Surface               100745 non-null  float64
#  4   Pools                 100745 non-null  int64
#  5   Air Conditioner       100745 non-null  int64
#  6   Type                  100665 non-null  object
#  7   IsNewConstruction     100745 non-null  bool
#  8   Conservation State    100745 non-null  int64
#  9   Terrace               100745 non-null  int64
#  10  Autonomous Community  100745 non-null  object
#  11  Province              100745 non-null  object
#  12  City                  100745 non-null  object
#  13  Neighborhood          22687 non-null   object
# ...

# %%
data['Autonomous Community'].value_counts()
# Out:
# canarias                8190
# castilla-y-leon         6000
# pais-vasco              6000
# cataluna                6000
# extremadura             6000
# region-de-murcia        6000
# madrid                  6000
# galicia                 6000
# la-rioja                5970
# cantabria               5970
# castilla-la-mancha      5970
# comunitat-valenciana    5940
# baleares                5940
# asturias                5910
# aragon                  5850
# andalucia               5730
# navarra                 3275
# Name: Autonomous Community, dtype: int64

# %%
pd.value_counts(data.dtypes)
# Out:
# object     11
# int64       7
# float64     3
# bool        1
# dtype: int64

# %%
data.describe(exclude='number')
# Out:
#           Type IsNewConstruction Autonomous Community Province  \
# count   100665            100745               100745   100745
# unique      11                 2                   17       50
# top       Flat             False             canarias   Murcia
# freq     54820             97532                 8190     6000
#
#                      City Neighborhood Ditricts     Municipality ZipCode  \
# count              100745        22687    63235           100744  100739
# unique               4071         1246     2260             4067    6309
# top      Madrid Capital\"     Gran Via   Centro   Madrid Capital   06800
# freq                 3008          482     6100             3008     663
#
#                   Agency            Publ_Date Descriptions
# count              99765               100745        99911
# unique              8138                60947        93912
# top     Haya Real Estate  2022-03-18 01:00:02         "\",
# ...

# %%
data.describe()
# Out:
#               Price      Bathrooms          Rooms       Surface  \
# count  1.007450e+05  100745.000000  100745.000000  1.007450e+05
# mean   2.662190e+05       1.939580       3.064638  7.520972e+02
# std    6.095590e+05      12.567522       1.575091  5.546765e+04
# min    0.000000e+00       0.000000       0.000000  0.000000e+00
# 25%    9.120000e+04       1.000000       2.000000  7.900000e+01
# 50%    1.550000e+05       2.000000       3.000000  1.040000e+02
# 75%    2.724400e+05       2.000000       4.000000  1.680000e+02
# max    1.200000e+08    2008.000000      99.000000  1.100000e+07
#
#                Pools  Air Conditioner  Conservation State        Terrace  \
# count  100745.000000    100745.000000       100745.000000  100745.000000
# mean        0.103946         0.225014            0.984098       0.416001
# std         0.305191         0.417593            1.363537       0.492896
# min         0.000000         0.000000            0.000000       0.000000
# ...

# %%
plt.figure(figsize=(20,20))
plt.imshow(data.isna(), aspect="auto", interpolation="nearest", cmap="gray")
plt.xlabel("Column")
plt.ylabel("Index")
plt.show()

# %%
data = data.drop(["Neighborhood", "Ditricts"], axis=1)

# %%
data.describe()
# Out:
#               Price      Bathrooms          Rooms       Surface  \
# count  1.007450e+05  100745.000000  100745.000000  1.007450e+05
# mean   2.662190e+05       1.939580       3.064638  7.520972e+02
# std    6.095590e+05      12.567522       1.575091  5.546765e+04
# min    0.000000e+00       0.000000       0.000000  0.000000e+00
# 25%    9.120000e+04       1.000000       2.000000  7.900000e+01
# 50%    1.550000e+05       2.000000       3.000000  1.040000e+02
# 75%    2.724400e+05       2.000000       4.000000  1.680000e+02
# max    1.200000e+08    2008.000000      99.000000  1.100000e+07
#
#                Pools  Air Conditioner  Conservation State        Terrace  \
# count  100745.000000    100745.000000       100745.000000  100745.000000
# mean        0.103946         0.225014            0.984098       0.416001
# std         0.305191         0.417593            1.363537       0.492896
# min         0.000000         0.000000            0.000000       0.000000
# ...

# %%
len(data.loc[data['Latitude'] == 0])
# Out:
# 13

# %%
data = data.loc[data['Price'] != 0]
data = data.loc[data['Surface'] != 0]
data.shape
# Out:
# (99535, 20)

# %%
plt.scatter(data['Surface'], data['Price'])
plt.show()

# %%
plt.boxplot(data['Price'])
plt.show()

# %%
data.mode()
# Out:
#     Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  Type  \
# 0  120000          2      3     90.0      0                0  Flat
#
#    IsNewConstruction  Conservation State  Terrace Autonomous Community  \
# 0              False                   0        0             canarias
#
#   Province               City     Municipality ZipCode            Agency  \
# 0   Murcia   Madrid Capital\"   Madrid Capital   06800  Haya Real Estate
#
#    Latitude  Longitude            Publ_Date Descriptions
# 0  37.87954  -1.102995  2022-03-18 01:00:02         "\",

# %%
'''sns.set(rc={"figure.figsize":(30, 30)})
sns.boxplot(x=data['Autonomous Community'], y=data['Price'])'''
# Out:
# 'sns.set(rc={"figure.figsize":(30, 30)})\nsns.boxplot(x=data[\'Autonomous Community\'], y=data[\'Price\'])'

# %%
'''corr_ma = data.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()'''
# Out:
# 'corr_ma = data.corr()\nsns.heatmap(corr_ma, annot=True)\nplt.show()'

# %%
#sns.regplot(x=data['Price'], y=data['Surface'])

# %%
def tukeysoutliers (df):
    q1= df['Price'].quantile(0.25)
    q3= df['Price'].quantile(0.75)
    iqr = q3 -q1
    return q3 + 1.5 * iqr

# %%
plt.boxplot(data.Price)
plt.show()

# %%
#data = data.loc[data['Price'] < upper]

# %%
plt.scatter(data.Surface, data.Price)

# %%
def tukeysoutliers (df, column):
    q1= df[column].quantile(0.25)
    q3= df[column].quantile(0.75)
    iqr = q3 -q1
    return q3 + 1.5 * iqr

# %%
outliers = tukeysoutliers (data, 'Price')

# %%
data = data.loc[data['Price'] < 2337500]

# %%
tukeysoutliers(data, 'Surface')
# Out:
# 284.0

# %%
data = data.loc[data['Surface'] < 1000]

# %%
plt.scatter(data.Surface, data.Price)
plt.show()

# %%
data.loc[data['Surface'] == 1].shape
# Out:
# (0, 20)

# %%
data = data.loc[data['Surface'] != 1]

# %%
plt.scatter(data.Surface, data.Price)
plt.show()

# %%
data.shape
# Out:
# (97727, 20)

# %%
sns.set(rc={"figure.figsize":(30, 30)})
sns.boxplot(x=data['Autonomous Community'], y=data['Surface'])
plt.show()

# %%
q1= data['Surface'].quantile(0.25)
q3= data['Surface'].quantile(0.75)
iqr = q3 -q1

lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

# %%
upper
# Out:
# 284.0

# %%
#data = data.loc[data['Surface'] < upper]

# %%
data
# Out:
#          Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  \
# 0       129900          2      3     90.0      0                0
# 1       175000          2      3    112.0      0                0
# 2        55000          1      4    100.0      0                0
# 3        36000          1      3     56.0      0                0
# 4        55000          1      3     60.0      0                0
# ...        ...        ...    ...      ...    ...              ...
# 100739   42200          1      3     71.0      0                0
# 100741  600000          4      5    380.0      0                0
# 100742  231000          2      1     55.0      0                0
# 100743  121500          1      2     74.0      0                0
# 100744  235000          1      1     66.0      0                0
#
#                 Type  IsNewConstruction  Conservation State  Terrace  \
# 0               Flat              False                   0        1
# ...

# %%
plt.boxplot(data['Surface'])
plt.show()

# %%
#sns.regplot(x=data['Price'], y=data['Surface'])

# %%
corr_ma = data.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()

# %%
data['Autonomous Community'].value_counts()
# Out:
# canarias                7966
# cantabria               5912
# cataluna                5898
# region-de-murcia        5897
# galicia                 5876
# castilla-y-leon         5874
# comunitat-valenciana    5865
# castilla-la-mancha      5861
# pais-vasco              5839
# extremadura             5832
# la-rioja                5831
# madrid                  5813
# asturias                5794
# andalucia               5615
# aragon                  5598
# baleares                5285
# navarra                 2971
# Name: Autonomous Community, dtype: int64

# %%
data_mean = data.groupby('Autonomous Community').mean().sort_values(by='Price', ascending=False)

# %%
data_mean
# Out:
#                               Price  Bathrooms     Rooms     Surface  \
# Autonomous Community
# baleares              535809.015326   2.119205  3.246168  183.599243
# madrid                411210.272321   2.616549  2.936006  137.859625
# cataluna              352266.860461   1.912343  3.238725  141.288911
# pais-vasco            314961.378489   1.676143  2.911800  116.777017
# canarias              264490.704871   1.854632  2.880241  149.646247
# andalucia             241685.669813   1.921995  2.999110  138.679786
# comunitat-valenciana  230005.123956   1.962489  3.067008  139.800512
# cantabria             202852.074932   1.847091  3.024865  149.746955
# galicia               199283.386828   1.953710  3.117937  154.648400
# navarra               179080.162235   1.729047  3.333221  172.948166
# asturias              172758.163618   1.736969  2.929410  127.126855
# region-de-murcia      154706.504324   1.812447  2.841445  131.965576
# ...

# %%
murcia = data.loc[data['Province'] == "Murcia"]
murcia
# Out:
#         Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  \
# 29850  239000          2      3    113.0      0                1
# 29851  468000          2      3    188.0      0                1
# 29852  370000          2      5    180.0      0                1
# 29853  220000          2      3    212.0      0                1
# 29854  129000          2      3    103.0      0                1
# ...       ...        ...    ...      ...    ...              ...
# 35845  177000          2      2     78.0      0                0
# 35846  114000          2      3     70.0      0                0
# 35847  100000          1      2    113.0      0                0
# 35848  175000          2      3    165.0      0                0
# 35849  426200          2      3    124.0      0                1
#
#                     Type  IsNewConstruction  Conservation State  Terrace  \
# 29850               Flat              False                   1        0
# ...

# %%
corr_ma = murcia.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()

# %%
madrid = data.loc[data['Province'] == "Madrid"]
segovia = data.loc[data['Province'] == "Segovia"]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121)
ax1.scatter(madrid.Price, madrid.Surface, label="Madrid")
ax1.scatter(murcia.Price, murcia.Surface, label="Murcia")
ax1.scatter(segovia.Price, segovia.Surface, label="Segovia")
plt.legend(loc='upper left')
plt.show()

# %%
corr_ma = segovia.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()

# %%
corr_ma = madrid.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()

# %%
data.groupby('ZipCode').count().sort_values(by='Price', ascending=False)
# Out:
#          Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  Type  \
# ZipCode
# 06800      643        643    643      643    643              643   643
# 26250      528        528    528      528    528              528   528
# 35110      510        510    510      510    510              510   510
# 26200      489        489    489      489    489              489   489
# 30740      466        466    466      466    466              466   466
# ...        ...        ...    ...      ...    ...              ...   ...
# 32764        1          1      1        1      1                1     1
# 32701        1          1      1        1      1                1     1
# 32695        1          1      1        1      1                1     1
# 32693        1          1      1        1      1                1     1
# AD700        1          1      1        1      1                1     1
#
#          IsNewConstruction  Conservation State  Terrace  Autonomous Community  \
# ZipCode
# ...

# %%
zipc = data.loc[data['ZipCode'] == '35110']

# %%
zipc.shape
# Out:
# (510, 20)

# %%
corr_ma = zipc.corr()
sns.heatmap(corr_ma, annot=True)
plt.show()

# %%
plt.scatter(zipc.Price, zipc.Surface)
m, b = np.polyfit(zipc.Price,zipc.Surface,1)
plt.plot(zipc.Price, m*zipc.Price+b, color="green")

# %%
data
# Out:
#          Price  Bathrooms  Rooms  Surface  Pools  Air Conditioner  \
# 0       129900          2      3     90.0      0                0
# 1       175000          2      3    112.0      0                0
# 2        55000          1      4    100.0      0                0
# 3        36000          1      3     56.0      0                0
# 4        55000          1      3     60.0      0                0
# ...        ...        ...    ...      ...    ...              ...
# 100739   42200          1      3     71.0      0                0
# 100741  600000          4      5    380.0      0                0
# 100742  231000          2      1     55.0      0                0
# 100743  121500          1      2     74.0      0                0
# 100744  235000          1      1     66.0      0                0
#
#                 Type  IsNewConstruction  Conservation State  Terrace  \
# 0               Flat              False                   0        1
# ...

# %%
data.to_csv("./EDAI.csv")
